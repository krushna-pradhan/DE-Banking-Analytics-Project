# %%
# %run "./02_read_with_schemas"

# %%
# Out:
# ...
# Creating Bronze daelta tables for all datasets
# ...
# Processing Customers...
# ...
# READING BANKING DATASETS WITH EXPLICIT SCHEMAS
# ...
#
# Reading datasets with explicit schemas...
#
# ✓ Customers: 1000 records
# ✓ Accounts: 1400 records
# ✓ Transactions: 10000 records
# ✓ Loans: 800 records
# ✓ Credit Cards: 900 records
# ✓ Branches: 50 records
# ✓ Employees: 500 records
# ✓ Fraud: 600 records
# ✓ Insurance: 700 records
# ✓ Support Tickets: 1200 records
#
# ✅ All 10 datasets loaded successfully with explicit schemas!
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-7947150309155308>, line 32
#      28 df_customers_with_metadata = df_customers.withColumn("ingestion_timestamp", current_timestamp()) \
#      29                                           .withColumn("source_file", lit("customers.csv")) \
# ...
