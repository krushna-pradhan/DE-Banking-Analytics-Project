# %%
# %sql
-- ============================================
-- REGISTER SILVER AND GOLD TABLES IN UNITY CATALOG
-- ============================================

USE CATALOG banking_catalog;

-- Bronze Tables
CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_customers
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/customers_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_accounts
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/accounts_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_transactions
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/transactions_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_loans
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/loans_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_credit_cards
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/credit_cards_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_branches
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/branches_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_employees
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/employees_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_fraud_transactions
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/fraud_transactions_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_insurance_products
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/insurance_products_bronze/';

CREATE TABLE IF NOT EXISTS banking_catalog.bronze.bronze_support_tickets
USING DELTA LOCATION 'abfss://bronze@sabankinganalytics.dfs.core.windows.net/customer_support_tickets_bronze/';


-- Silver Tables
CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_customers
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/customers_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_accounts
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/accounts_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_transactions
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/transactions_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_loans
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/loans_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_credit_cards
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/credit_cards_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_branches
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/branches_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_employees
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/employees_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_fraud_transactions
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/fraud_transactions_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_insurance_products
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/insurance_products_silver/';

CREATE TABLE IF NOT EXISTS banking_catalog.silver.silver_support_tickets
USING DELTA LOCATION 'abfss://silver@sabankinganalytics.dfs.core.windows.net/customer_support_tickets_silver/';

-- Gold Tables
CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_customer_360
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/customer_360/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_branch_performance
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/branch_performance/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_loan_portfolio
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/loan_portfolio/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_fraud_analysis
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/fraud_analysis/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_daily_transaction_trends
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/daily_transaction_trends/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_customer_support_metrics
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/customer_support_metrics/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_monthly_financial_summary
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/monthly_financial_summary/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_employee_performance
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/employee_performance/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_cross_sell_insights
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/cross_sell_insights/';

CREATE TABLE IF NOT EXISTS banking_catalog.gold.gold_balance_distribution
USING DELTA LOCATION 'abfss://gold@sabankinganalytics.dfs.core.windows.net/balance_distribution/';

-- Verify all tables
SHOW TABLES IN banking_catalog.bronze;
SHOW TABLES IN banking_catalog.silver;
SHOW TABLES IN banking_catalog.gold;

-- Record counts verification
SELECT 'silver_customers' as table_name, COUNT(*) as record_count FROM banking_catalog.silver.silver_customers
UNION ALL
SELECT 'silver_accounts', COUNT(*) FROM banking_catalog.silver.silver_accounts
UNION ALL
SELECT 'silver_transactions', COUNT(*) FROM banking_catalog.silver.silver_transactions
UNION ALL
SELECT 'silver_loans', COUNT(*) FROM banking_catalog.silver.silver_loans
UNION ALL
SELECT 'silver_credit_cards', COUNT(*) FROM banking_catalog.silver.silver_credit_cards
UNION ALL
SELECT 'gold_customer_360', COUNT(*) FROM banking_catalog.gold.gold_customer_360
UNION ALL
SELECT 'gold_branch_performance', COUNT(*) FROM banking_catalog.gold.gold_branch_performance;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_name</th><th>record_count</th></tr></thead><tbody><tr><td>silver_customers</td><td>1000</td></tr><tr><td>silver_accounts</td><td>1400</td></tr><tr><td>silver_transactions</td><td>10000</td></tr><tr><td>silver_loans</td><td>800</td></tr><tr><td>silver_credit_cards</td><td>900</td></tr><tr><td>gold_customer_360</td><td>1000</td></tr><tr><td>gold_branch_performance</td><td>50</td></tr></tbody></table></div>
